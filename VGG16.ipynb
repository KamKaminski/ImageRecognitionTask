# %% [markdown]
# Ensuring we use apple m1 metal for processing power

# %%
import torch
if torch.backends.mps.is_available():
    mps_device = torch.device("mps")
    x = torch.ones(1, device=mps_device)
    print (x)
else:
    print ("MPS device not found.")
# Out:
# tensor([1.], device='mps:0')

# %% [markdown]
# Data train split minimum 20 faces

# %%
import os
import shutil
import numpy as np
from sklearn.model_selection import train_test_split
from keras.applications.vgg16 import VGG16
from keras.models import Model
from keras.layers import Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator

source_dir = 'photos/lfw_funneled'
categories = os.listdir(source_dir)

# directories for training and testing sets
train_dir = 'photos/train_set'
test_dir = 'photos/test_set'

# training and testing directories
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# For each category(person), split images into training and testing sets
for category in categories:
    # Error checking skips if this is a file, not a directory
    if not os.path.isdir(os.path.join(source_dir, category)):
        continue
    
    image_list = os.listdir(os.path.join(source_dir, category))
    
    # We only only need those with minimum 20 faces
    if len(image_list) < 20:
        # print(f'Skipping {category}, only {len(image_list)} images found')
        continue
    
    # We should shuffle the image list
    np.random.shuffle(image_list)

    # Splitting data into training and testing sets
    train_list, test_list = train_test_split(image_list, test_size=0.2)

    # category directories in training and testing directories
    os.makedirs(os.path.join(train_dir, category), exist_ok=True)
    os.makedirs(os.path.join(test_dir, category), exist_ok=True)

    # Copy images to appropriate directories
    for image in train_list:
        shutil.copy(os.path.join(source_dir, category, image), os.path.join(train_dir, category))
    for image in test_list:
        shutil.copy(os.path.join(source_dir, category, image), os.path.join(test_dir, category))

    # Copy images to appropriate directories
    for image in train_list:
        shutil.copy(os.path.join(source_dir, category, image), os.path.join(train_dir, category))
    for image in test_list:
        shutil.copy(os.path.join(source_dir, category, image), os.path.join(test_dir, category))

# %%
from keras.applications.vgg16 import VGG16
from keras.models import Model
from keras.layers import Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator


# Load pre-trained the VGG16 model on imagenet
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(64, 64, 3))

# Some manipulation
x = Flatten()(base_model.output)

x = Dense(1024, activation='relu')(x)

# This parameter depends on number of our classes/people, either we know it or error will tell us...
output = Dense(62, activation='softmax')(x)

# defining the model
model = Model(inputs=base_model.input, outputs=output)

for layer in base_model.layers:
    layer.trainable = False

# Compilation of the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory('photos/train_set', target_size=(64, 64), batch_size=32, class_mode='categorical')
test_set = test_datagen.flow_from_directory('photos/test_set', target_size=(64, 64), batch_size=32, class_mode='categorical')

# Train the model
model.fit(training_set, epochs=15, validation_data=test_set)
# Out:
# Found 2892 images belonging to 62 classes.
# Found 1131 images belonging to 62 classes.
# Epoch 1/15
# 2023-05-18 18:38:24.666384: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 91/91 [==============================] - 28s 305ms/step - loss: 3.4927 - accuracy: 0.2044 - val_loss: 2.9054 - val_accuracy: 0.2405
# Epoch 2/15
# 91/91 [==============================] - 27s 302ms/step - loss: 2.8059 - accuracy: 0.3050 - val_loss: 2.3596 - val_accuracy: 0.3599
# Epoch 3/15
# 91/91 [==============================] - 28s 306ms/step - loss: 2.4242 - accuracy: 0.3814 - val_loss: 2.1681 - val_accuracy: 0.4076
# Epoch 4/15
# 91/91 [==============================] - 29s 321ms/step - loss: 2.1813 - accuracy: 0.4108 - val_loss: 1.9010 - val_accuracy: 0.4996
# Epoch 5/15
# 91/91 [==============================] - 28s 303ms/step - loss: 1.9578 - accuracy: 0.4703 - val_loss: 1.6391 - val_accuracy: 0.5632
# Epoch 6/15
# 91/91 [==============================] - 22s 246ms/step - loss: 1.8127 - accuracy: 0.4965 - val_loss: 1.5982 - val_accuracy: 0.5836
# Epoch 7/15
# 91/91 [==============================] - 22s 246ms/step - loss: 1.6821 - accuracy: 0.5377 - val_loss: 1.4274 - val_accuracy: 0.6048
# Epoch 8/15
# 91/91 [==============================] - 22s 245ms/step - loss: 1.5313 - accuracy: 0.5678 - val_loss: 1.3570 - val_accuracy: 0.6508
# Epoch 9/15
# 91/91 [==============================] - 22s 246ms/step - loss: 1.4217 - accuracy: 0.5999 - val_loss: 1.2868 - val_accuracy: 0.6340
# Epoch 10/15
# 91/91 [==============================] - 23s 248ms/step - loss: 1.3335 - accuracy: 0.6255 - val_loss: 1.1195 - val_accuracy: 0.6958
# Epoch 11/15
# 91/91 [==============================] - 23s 248ms/step - loss: 1.2249 - accuracy: 0.6515 - val_loss: 1.1927 - val_accuracy: 0.6596
# Epoch 12/15
# 91/91 [==============================] - 23s 249ms/step - loss: 1.1547 - accuracy: 0.6601 - val_loss: 1.0054 - val_accuracy: 0.7259
# Epoch 13/15
# 91/91 [==============================] - 22s 242ms/step - loss: 1.0693 - accuracy: 0.6981 - val_loss: 0.9913 - val_accuracy: 0.7418
# Epoch 14/15
# 91/91 [==============================] - 22s 243ms/step - loss: 0.9715 - accuracy: 0.7116 - val_loss: 1.0298 - val_accuracy: 0.7126
# Epoch 15/15
# 91/91 [==============================] - 22s 243ms/step - loss: 0.9844 - accuracy: 0.7140 - val_loss: 0.8184 - val_accuracy: 0.8028

# %%
from keras.applications.vgg16 import VGG16
from keras.models import Model
from keras.layers import Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator

base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

x = Flatten()(base_model.output)

x = Dense(1024, activation='relu')(x)

output = Dense(62, activation='softmax')(x) 

model = Model(inputs=base_model.input, outputs=output)

for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory('photos/train_set', target_size=(224, 224), batch_size=32, class_mode='categorical')
test_set = test_datagen.flow_from_directory('photos/test_set', target_size=(224, 224), batch_size=32, class_mode='categorical')

model.fit(training_set, epochs=15, validation_data=test_set)
# Out:
# Found 2892 images belonging to 62 classes.
# Found 1131 images belonging to 62 classes.
# Epoch 1/15
# 91/91 [==============================] - 246s 3s/step - loss: 4.7528 - accuracy: 0.2441 - val_loss: 2.4915 - val_accuracy: 0.3722
# Epoch 2/15
# 91/91 [==============================] - 251s 3s/step - loss: 2.0666 - accuracy: 0.5048 - val_loss: 1.4538 - val_accuracy: 0.6569
# Epoch 3/15
# 91/91 [==============================] - 250s 3s/step - loss: 1.3244 - accuracy: 0.6746 - val_loss: 1.0593 - val_accuracy: 0.7321
# Epoch 4/15
# 91/91 [==============================] - 245s 3s/step - loss: 0.9026 - accuracy: 0.7766 - val_loss: 0.7155 - val_accuracy: 0.8258
# Epoch 5/15
# 91/91 [==============================] - 244s 3s/step - loss: 0.6061 - accuracy: 0.8562 - val_loss: 0.4220 - val_accuracy: 0.8930
# Epoch 6/15
# 91/91 [==============================] - 245s 3s/step - loss: 0.4031 - accuracy: 0.9160 - val_loss: 0.2789 - val_accuracy: 0.9355
# Epoch 7/15
# 91/91 [==============================] - 239s 3s/step - loss: 0.3142 - accuracy: 0.9281 - val_loss: 0.2383 - val_accuracy: 0.9434
# Epoch 8/15
# 91/91 [==============================] - 247s 3s/step - loss: 0.2338 - accuracy: 0.9540 - val_loss: 0.1863 - val_accuracy: 0.9629
# Epoch 9/15
# 91/91 [==============================] - 253s 3s/step - loss: 0.1814 - accuracy: 0.9633 - val_loss: 0.1780 - val_accuracy: 0.9602
# Epoch 10/15
# 91/91 [==============================] - 248s 3s/step - loss: 0.1341 - accuracy: 0.9748 - val_loss: 0.1504 - val_accuracy: 0.9664
# Epoch 11/15
# 91/91 [==============================] - 247s 3s/step - loss: 0.1097 - accuracy: 0.9831 - val_loss: 0.1244 - val_accuracy: 0.9752
# Epoch 12/15
# 91/91 [==============================] - 250s 3s/step - loss: 0.0806 - accuracy: 0.9900 - val_loss: 0.1165 - val_accuracy: 0.9735
# Epoch 13/15
# 91/91 [==============================] - 251s 3s/step - loss: 0.0799 - accuracy: 0.9869 - val_loss: 0.1137 - val_accuracy: 0.9717
# Epoch 14/15
# 91/91 [==============================] - 246s 3s/step - loss: 0.0610 - accuracy: 0.9927 - val_loss: 0.0978 - val_accuracy: 0.9779
# Epoch 15/15
# 91/91 [==============================] - 250s 3s/step - loss: 0.0419 - accuracy: 0.9969 - val_loss: 0.0843 - val_accuracy: 0.9797

# %%
model.save('98%.h5')

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np

# Load the saved model
model = load_model('98%.h5')



# retrieve  the labels map from the training set
label_map = (training_set.class_indices)
label_map = dict((v,k) for k,v in label_map.items())

def classify_image(image_path, model, label_map):
    # Load the images
    img = load_img(image_path, target_size=(224, 224))

    # Convert the images to array
    img_array = img_to_array(img)

    # dimensions must  match the shape that model expects
    img_batch = np.expand_dims(img_array, axis=0)

    # normalisatiom of image
    img_preprocessed = img_batch / 255.

    # get the class of the image using our pretrianed model, verbose = reduces print size
    predictions = model.predict(img_preprocessed, verbose = 0)

    # get the class index that has the highest probability
    class_index = np.argmax(predictions[0])

    # finaly we get  the label of class
    class_label = label_map[class_index]

    return class_label

# %%
image_path = 'photos/train_set/Vladimir_Putin/Vladimir_Putin_0005.jpg'
class_label = classify_image(image_path, model, label_map)
print("This image is likely to be of class:", class_label)
# Out:
# This image is likely to be of class: Vladimir_Putin

# %% [markdown]
# Above works fine for singular images but we have thousands of images to test, lets make loop

# %%
import os

def classify_images_in_directory(directory_path, model, label_map):
    results = {}

    for subdir, dirs, files in os.walk(directory_path):
        for file in files:
            image_path = os.path.join(subdir, file)
            class_label = classify_image(image_path, model, label_map)
            file_name = os.path.splitext(os.path.basename(image_path))[0] 
            results[file_name] = class_label

    return results

directory_path = 'photos/test_set'
results = classify_images_in_directory(directory_path, model, label_map)

for image_name, class_label in results.items():
    print(f"\nThe image {image_name} is likely to be of class: {class_label}")
# Out:
# The image Jennifer_Aniston_0005 is likely to be of class: Jennifer_Aniston
#
# The image Jennifer_Aniston_0011 is likely to be of class: Jennifer_Aniston
#
# The image Jennifer_Aniston_0007 is likely to be of class: Jennifer_Aniston
#
# The image Jennifer_Aniston_0012 is likely to be of class: Jennifer_Aniston
#
# The image Jennifer_Aniston_0002 is likely to be of class: Jennifer_Aniston
#
# The image Jennifer_Aniston_0016 is likely to be of class: Jennifer_Aniston
#
# The image Jennifer_Aniston_0003 is likely to be of class: Jennifer_Aniston
#
# The image Jennifer_Aniston_0014 is likely to be of class: Jennifer_Aniston
#
# The image Jennifer_Aniston_0019 is likely to be of class: Jennifer_Aniston
#
# The image Tom_Daschle_0003 is likely to be of class: Tom_Daschle
#
# The image Tom_Daschle_0017 is likely to be of class: Tom_Daschle
#
# The image Tom_Daschle_0006 is likely to be of class: Tom_Daschle
#
# The image Tom_Daschle_0012 is likely to be of class: Tom_Daschle
#
# The image Tom_Daschle_0020 is likely to be of class: Tom_Daschle
#
# The image Tom_Daschle_0009 is likely to be of class: Donald_Rumsfeld
#
# The image Tom_Daschle_0021 is likely to be of class: Tom_Daschle
#
# The image Tom_Daschle_0019 is likely to be of class: Tom_Daschle
#
# The image Tom_Daschle_0025 is likely to be of class: Tom_Daschle
#
# The image Alvaro_Uribe_0022 is likely to be of class: Alvaro_Uribe
#
# The image Alvaro_Uribe_0009 is likely to be of class: Alvaro_Uribe
#
# The image Alvaro_Uribe_0034 is likely to be of class: Alvaro_Uribe
#
# The image Alvaro_Uribe_0025 is likely to be of class: Alvaro_Uribe
#
# The image Alvaro_Uribe_0019 is likely to be of class: Alvaro_Uribe
#
# The image Alvaro_Uribe_0027 is likely to be of class: Alvaro_Uribe
#
# The image Alvaro_Uribe_0003 is likely to be of class: Alvaro_Uribe
#
# The image Alvaro_Uribe_0016 is likely to be of class: Jose_Maria_Aznar
#
# The image Alvaro_Uribe_0014 is likely to be of class: Alvaro_Uribe
#
# The image Alvaro_Uribe_0011 is likely to be of class: Alvaro_Uribe
#
# The image Alvaro_Uribe_0010 is likely to be of class: Alvaro_Uribe
#
# The image Angelina_Jolie_0008 is likely to be of class: Angelina_Jolie
#
# The image Angelina_Jolie_0013 is likely to be of class: Angelina_Jolie
#
# The image Angelina_Jolie_0006 is likely to be of class: Angelina_Jolie
#
# The image Angelina_Jolie_0010 is likely to be of class: Angelina_Jolie
#
# The image Angelina_Jolie_0011 is likely to be of class: Angelina_Jolie
#
# The image Angelina_Jolie_0015 is likely to be of class: Angelina_Jolie
#
# The image Angelina_Jolie_0016 is likely to be of class: Angelina_Jolie
#
# The image Mahmoud_Abbas_0007 is likely to be of class: Mahmoud_Abbas
#
# The image Mahmoud_Abbas_0015 is likely to be of class: Mahmoud_Abbas
#
# The image Mahmoud_Abbas_0001 is likely to be of class: Mahmoud_Abbas
#
# The image Mahmoud_Abbas_0014 is likely to be of class: Mahmoud_Abbas
#
# The image Mahmoud_Abbas_0028 is likely to be of class: Mahmoud_Abbas
#
# The image Mahmoud_Abbas_0025 is likely to be of class: Mahmoud_Abbas
#
# The image Mahmoud_Abbas_0019 is likely to be of class: Mahmoud_Abbas
#
# The image Mahmoud_Abbas_0018 is likely to be of class: Mahmoud_Abbas
#
# The image Mahmoud_Abbas_0020 is likely to be of class: Mahmoud_Abbas
#
# The image Mahmoud_Abbas_0009 is likely to be of class: Mahmoud_Abbas
#
# The image Mahmoud_Abbas_0023 is likely to be of class: Mahmoud_Abbas
#
# The image Mahmoud_Abbas_0022 is likely to be of class: Mahmoud_Abbas
#
# The image Igor_Ivanov_0006 is likely to be of class: Igor_Ivanov
#
# The image Igor_Ivanov_0013 is likely to be of class: Igor_Ivanov
#
# The image Igor_Ivanov_0007 is likely to be of class: Igor_Ivanov
#
# The image Igor_Ivanov_0005 is likely to be of class: Igor_Ivanov
#
# The image Igor_Ivanov_0010 is likely to be of class: Igor_Ivanov
#
# The image Igor_Ivanov_0018 is likely to be of class: Vladimir_Putin
#
# The image Igor_Ivanov_0009 is likely to be of class: Igor_Ivanov
#
# The image Jiang_Zemin_0019 is likely to be of class: Jiang_Zemin
#
# The image Jiang_Zemin_0018 is likely to be of class: Jiang_Zemin
#
# The image Jiang_Zemin_0008 is likely to be of class: Jiang_Zemin
#
# The image Jiang_Zemin_0012 is likely to be of class: Jiang_Zemin
#
# The image Jiang_Zemin_0006 is likely to be of class: Jiang_Zemin
#
# The image Jiang_Zemin_0002 is likely to be of class: Jiang_Zemin
#
# The image Jiang_Zemin_0001 is likely to be of class: Jiang_Zemin
#
# The image John_Negroponte_0012 is likely to be of class: John_Negroponte
#
# The image John_Negroponte_0013 is likely to be of class: John_Negroponte
#
# The image John_Negroponte_0011 is likely to be of class: John_Negroponte
#
# The image John_Negroponte_0014 is likely to be of class: John_Negroponte
#
# The image John_Negroponte_0003 is likely to be of class: John_Negroponte
#
# The image John_Negroponte_0017 is likely to be of class: John_Negroponte
#
# The image John_Negroponte_0002 is likely to be of class: John_Negroponte
#
# The image John_Negroponte_0024 is likely to be of class: John_Negroponte
#
# The image John_Negroponte_0019 is likely to be of class: John_Negroponte
#
# The image John_Negroponte_0025 is likely to be of class: John_Negroponte
#
# The image John_Negroponte_0031 is likely to be of class: John_Negroponte
#
# The image John_Negroponte_0023 is likely to be of class: John_Negroponte
#
# The image Jacques_Chirac_0043 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0041 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0045 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0050 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0044 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0046 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0034 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0009 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0023 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0037 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0033 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0027 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0019 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0031 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0015 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0028 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0007 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0038 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0005 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0039 is likely to be of class: Jacques_Chirac
#
# The image Jacques_Chirac_0048 is likely to be of class: Jacques_Chirac
#
# The image Rudolph_Giuliani_0009 is likely to be of class: Angelina_Jolie
#
# The image Rudolph_Giuliani_0022 is likely to be of class: Rudolph_Giuliani
#
# The image Rudolph_Giuliani_0018 is likely to be of class: Rudolph_Giuliani
#
# The image Rudolph_Giuliani_0015 is likely to be of class: Rudolph_Giuliani
#
# The image Rudolph_Giuliani_0017 is likely to be of class: Rudolph_Giuliani
#
# The image Rudolph_Giuliani_0002 is likely to be of class: Rudolph_Giuliani
#
# The image Rudolph_Giuliani_0012 is likely to be of class: Rudolph_Giuliani
#
# The image Rudolph_Giuliani_0011 is likely to be of class: Rudolph_Giuliani
#
# The image Rudolph_Giuliani_0005 is likely to be of class: Rudolph_Giuliani
#
# The image Rudolph_Giuliani_0004 is likely to be of class: Rudolph_Giuliani
#
# The image Gerhard_Schroeder_0081 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0056 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0042 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0043 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0109 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0082 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0054 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0068 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0097 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0079 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0045 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0092 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0090 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0084 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0053 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0085 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0091 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0020 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0034 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0008 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0022 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0036 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0037 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0023 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0026 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0018 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0031 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0003 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0002 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0012 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0038 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0010 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0103 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0063 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0076 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0061 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0105 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0058 is likely to be of class: Gerhard_Schroeder
#
# The image Gerhard_Schroeder_0107 is likely to be of class: Gerhard_Schroeder
#
# The image Jose_Maria_Aznar_0022 is likely to be of class: Jose_Maria_Aznar
#
# The image Jose_Maria_Aznar_0008 is likely to be of class: Jose_Maria_Aznar
#
# The image Jose_Maria_Aznar_0021 is likely to be of class: Jose_Maria_Aznar
#
# The image Jose_Maria_Aznar_0004 is likely to be of class: Jose_Maria_Aznar
#
# The image Jose_Maria_Aznar_0005 is likely to be of class: Jose_Maria_Aznar
#
# The image Jose_Maria_Aznar_0007 is likely to be of class: Jose_Maria_Aznar
#
# The image Jose_Maria_Aznar_0006 is likely to be of class: Jose_Maria_Aznar
#
# The image Jose_Maria_Aznar_0016 is likely to be of class: Jose_Maria_Aznar
#
# The image Jose_Maria_Aznar_0015 is likely to be of class: Jose_Maria_Aznar
#
# The image Roh_Moo-hyun_0010 is likely to be of class: Roh_Moo-hyun
#
# The image Roh_Moo-hyun_0006 is likely to be of class: Roh_Moo-hyun
#
# The image Roh_Moo-hyun_0013 is likely to be of class: Roh_Moo-hyun
#
# The image Roh_Moo-hyun_0007 is likely to be of class: Roh_Moo-hyun
#
# The image Roh_Moo-hyun_0003 is likely to be of class: Roh_Moo-hyun
#
# The image Roh_Moo-hyun_0016 is likely to be of class: Roh_Moo-hyun
#
# The image Roh_Moo-hyun_0002 is likely to be of class: Roh_Moo-hyun
#
# The image Roh_Moo-hyun_0015 is likely to be of class: Roh_Moo-hyun
#
# The image Roh_Moo-hyun_0024 is likely to be of class: Roh_Moo-hyun
#
# The image Roh_Moo-hyun_0019 is likely to be of class: Roh_Moo-hyun
#
# The image Roh_Moo-hyun_0022 is likely to be of class: Roh_Moo-hyun
#
# The image Hamid_Karzai_0019 is likely to be of class: Hamid_Karzai
#
# The image Hamid_Karzai_0009 is likely to be of class: Hamid_Karzai
#
# The image Hamid_Karzai_0020 is likely to be of class: Hamid_Karzai
#
# The image Hamid_Karzai_0012 is likely to be of class: Hamid_Karzai
#
# The image Hamid_Karzai_0011 is likely to be of class: Hamid_Karzai
#
# The image Hamid_Karzai_0010 is likely to be of class: Hamid_Karzai
#
# The image Hamid_Karzai_0004 is likely to be of class: Gerhard_Schroeder
#
# The image Hamid_Karzai_0017 is likely to be of class: Hamid_Karzai
#
# The image Hamid_Karzai_0016 is likely to be of class: Hamid_Karzai
#
# The image Vladimir_Putin_0003 is likely to be of class: Vladimir_Putin
#
# The image Vladimir_Putin_0017 is likely to be of class: Vladimir_Putin
#
# The image Vladimir_Putin_0001 is likely to be of class: Vladimir_Putin
#
# The image Vladimir_Putin_0028 is likely to be of class: Vladimir_Putin
#
# The image Vladimir_Putin_0010 is likely to be of class: Vladimir_Putin
#
# The image Vladimir_Putin_0011 is likely to be of class: Vladimir_Putin
#
# The image Vladimir_Putin_0039 is likely to be of class: Vladimir_Putin
#
# The image Vladimir_Putin_0013 is likely to be of class: Vladimir_Putin
#
# The image Vladimir_Putin_0012 is likely to be of class: Vladimir_Putin
#
# The image Vladimir_Putin_0048 is likely to be of class: Vladimir_Putin
#
# The image Vladimir_Putin_0046 is likely to be of class: Vladimir_Putin
#
# The image Vladimir_Putin_0020 is likely to be of class: Vladimir_Putin
#
# The image Vladimir_Putin_0034 is likely to be of class: Vladimir_Putin
#
# The image Vladimir_Putin_0008 is likely to be of class: Vladimir_Putin
#
# The image Vladimir_Putin_0025 is likely to be of class: Vladimir_Putin
#
# The image Vladimir_Putin_0024 is likely to be of class: Vladimir_Putin
#
# The image Vladimir_Putin_0027 is likely to be of class: Vladimir_Putin
#
# The image Vladimir_Putin_0033 is likely to be of class: Vladimir_Putin
#
# The image Jennifer_Lopez_0011 is likely to be of class: Jennifer_Lopez
#
# The image Jennifer_Lopez_0004 is likely to be of class: Jennifer_Lopez
#
# The image Jennifer_Lopez_0010 is likely to be of class: Jennifer_Lopez
#
# The image Jennifer_Lopez_0006 is likely to be of class: Jennifer_Lopez
#
# The image Jennifer_Lopez_0007 is likely to be of class: Jennifer_Lopez
#
# The image Jennifer_Lopez_0017 is likely to be of class: Angelina_Jolie
#
# The image Jennifer_Lopez_0014 is likely to be of class: Jennifer_Lopez
#
# The image Jennifer_Lopez_0018 is likely to be of class: Jennifer_Lopez
#
# The image Jennifer_Lopez_0009 is likely to be of class: Jennifer_Lopez
#
# The image Tony_Blair_0017 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0003 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0001 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0012 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0061 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0101 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0129 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0100 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0074 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0060 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0063 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0077 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0088 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0113 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0106 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0072 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0058 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0070 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0110 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0054 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0068 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0120 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0109 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0096 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0082 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0080 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0057 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0043 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0123 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0122 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0042 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0095 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0085 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0052 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0046 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0132 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0053 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0084 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0092 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0131 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0124 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0130 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0044 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0078 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0037 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0143 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0142 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0036 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0034 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0021 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0031 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0025 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0144 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0030 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0018 is likely to be of class: Tony_Blair
#
# The image Tony_Blair_0026 is likely to be of class: Tony_Blair
#
# The image Jack_Straw_0016 is likely to be of class: Jack_Straw
#
# The image Jack_Straw_0003 is likely to be of class: Jack_Straw
#
# The image Jack_Straw_0015 is likely to be of class: Jack_Straw
#
# The image Jack_Straw_0028 is likely to be of class: Jack_Straw
#
# The image Jack_Straw_0011 is likely to be of class: Jack_Straw
#
# The image Jack_Straw_0022 is likely to be of class: Jack_Straw
#
# The image Jack_Straw_0020 is likely to be of class: Jack_Straw
#
# The image Jack_Straw_0008 is likely to be of class: Jack_Straw
#
# The image Jack_Straw_0009 is likely to be of class: Jack_Straw
#
# The image Jack_Straw_0019 is likely to be of class: Jack_Straw
#
# The image Jack_Straw_0025 is likely to be of class: Jack_Straw
#
# The image Jack_Straw_0024 is likely to be of class: Jack_Straw
#
# The image Pete_Sampras_0019 is likely to be of class: Pete_Sampras
#
# The image Pete_Sampras_0009 is likely to be of class: Pete_Sampras
#
# The image Pete_Sampras_0008 is likely to be of class: Pete_Sampras
#
# The image Pete_Sampras_0022 is likely to be of class: Pete_Sampras
#
# The image Pete_Sampras_0012 is likely to be of class: Pete_Sampras
#
# The image Pete_Sampras_0013 is likely to be of class: Pete_Sampras
#
# The image Pete_Sampras_0014 is likely to be of class: Pete_Sampras
#
# The image Pete_Sampras_0015 is likely to be of class: Pete_Sampras
#
# The image Pete_Sampras_0003 is likely to be of class: Pete_Sampras
#
# The image Pete_Sampras_0016 is likely to be of class: Pete_Sampras
#
# The image Amelie_Mauresmo_0016 is likely to be of class: Amelie_Mauresmo
#
# The image Amelie_Mauresmo_0007 is likely to be of class: Amelie_Mauresmo
#
# The image Amelie_Mauresmo_0006 is likely to be of class: Amelie_Mauresmo
#
# The image Amelie_Mauresmo_0004 is likely to be of class: Pete_Sampras
#
# The image Amelie_Mauresmo_0020 is likely to be of class: Amelie_Mauresmo
#
# The image Amelie_Mauresmo_0008 is likely to be of class: Amelie_Mauresmo
#
# The image Amelie_Mauresmo_0009 is likely to be of class: Amelie_Mauresmo
#
# The image Amelie_Mauresmo_0021 is likely to be of class: Amelie_Mauresmo
#
# The image Amelie_Mauresmo_0019 is likely to be of class: Amelie_Mauresmo
#
# The image Bill_Clinton_0026 is likely to be of class: Bill_Clinton
#
# The image Bill_Clinton_0021 is likely to be of class: Bill_Clinton
#
# The image Bill_Clinton_0020 is likely to be of class: Bill_Clinton
#
# The image Bill_Clinton_0008 is likely to be of class: Bill_Clinton
#
# The image Bill_Clinton_0005 is likely to be of class: Bill_Clinton
#
# The image Bill_Clinton_0004 is likely to be of class: Bill_Clinton
#
# The image Bill_Clinton_0006 is likely to be of class: Bill_Clinton
#
# The image Bill_Clinton_0007 is likely to be of class: Bill_Clinton
#
# The image Bill_Clinton_0017 is likely to be of class: Bill_Clinton
#
# The image Bill_Clinton_0003 is likely to be of class: Bill_Clinton
#
# The image Bill_Clinton_0029 is likely to be of class: Bill_Clinton
#
# The image Nestor_Kirchner_0023 is likely to be of class: Nestor_Kirchner
#
# The image Nestor_Kirchner_0036 is likely to be of class: Nestor_Kirchner
#
# The image Nestor_Kirchner_0022 is likely to be of class: Nestor_Kirchner
#
# The image Nestor_Kirchner_0009 is likely to be of class: Nestor_Kirchner
#
# The image Nestor_Kirchner_0021 is likely to be of class: Nestor_Kirchner
#
# The image Nestor_Kirchner_0025 is likely to be of class: Nestor_Kirchner
#
# The image Nestor_Kirchner_0024 is likely to be of class: Nestor_Kirchner
#
# The image Nestor_Kirchner_0032 is likely to be of class: Nestor_Kirchner
#
# The image Nestor_Kirchner_0027 is likely to be of class: Paul_Bremer
#
# The image Nestor_Kirchner_0016 is likely to be of class: Nestor_Kirchner
#
# The image Nestor_Kirchner_0017 is likely to be of class: Nestor_Kirchner
#
# The image Nestor_Kirchner_0001 is likely to be of class: Nestor_Kirchner
#
# The image Nestor_Kirchner_0029 is likely to be of class: Nestor_Kirchner
#
# The image Nestor_Kirchner_0004 is likely to be of class: Nestor_Kirchner
#
# The image Naomi_Watts_0008 is likely to be of class: Naomi_Watts
#
# The image Naomi_Watts_0018 is likely to be of class: Naomi_Watts
#
# The image Naomi_Watts_0017 is likely to be of class: Naomi_Watts
#
# The image Naomi_Watts_0002 is likely to be of class: Naomi_Watts
#
# The image Naomi_Watts_0015 is likely to be of class: Naomi_Watts
#
# The image Naomi_Watts_0011 is likely to be of class: Naomi_Watts
#
# The image Naomi_Watts_0010 is likely to be of class: Naomi_Watts
#
# The image Naomi_Watts_0012 is likely to be of class: Laura_Bush
#
# The image Naomi_Watts_0007 is likely to be of class: Naomi_Watts
#
# The image Kofi_Annan_0022 is likely to be of class: Colin_Powell
#
# The image Kofi_Annan_0009 is likely to be of class: Kofi_Annan
#
# The image Kofi_Annan_0008 is likely to be of class: Kofi_Annan
#
# The image Kofi_Annan_0018 is likely to be of class: Kofi_Annan
#
# The image Kofi_Annan_0025 is likely to be of class: Kofi_Annan
#
# The image Kofi_Annan_0032 is likely to be of class: Kofi_Annan
#
# The image Kofi_Annan_0003 is likely to be of class: Kofi_Annan
#
# The image Kofi_Annan_0029 is likely to be of class: Kofi_Annan
#
# The image Kofi_Annan_0011 is likely to be of class: Kofi_Annan
#
# The image Kofi_Annan_0004 is likely to be of class: Kofi_Annan
#
# The image Kofi_Annan_0010 is likely to be of class: Kofi_Annan
#
# The image Kofi_Annan_0007 is likely to be of class: Kofi_Annan
#
# The image Luiz_Inacio_Lula_da_Silva_0027 is likely to be of class: Luiz_Inacio_Lula_da_Silva
#
# The image Luiz_Inacio_Lula_da_Silva_0026 is likely to be of class: Luiz_Inacio_Lula_da_Silva
#
# The image Luiz_Inacio_Lula_da_Silva_0009 is likely to be of class: Luiz_Inacio_Lula_da_Silva
#
# The image Luiz_Inacio_Lula_da_Silva_0034 is likely to be of class: Luiz_Inacio_Lula_da_Silva
#
# The image Luiz_Inacio_Lula_da_Silva_0020 is likely to be of class: Luiz_Inacio_Lula_da_Silva
#
# The image Luiz_Inacio_Lula_da_Silva_0008 is likely to be of class: Luiz_Inacio_Lula_da_Silva
#
# The image Luiz_Inacio_Lula_da_Silva_0022 is likely to be of class: Luiz_Inacio_Lula_da_Silva
#
# The image Luiz_Inacio_Lula_da_Silva_0044 is likely to be of class: Luiz_Inacio_Lula_da_Silva
#
# The image Luiz_Inacio_Lula_da_Silva_0042 is likely to be of class: Luiz_Inacio_Lula_da_Silva
#
# The image Luiz_Inacio_Lula_da_Silva_0048 is likely to be of class: Luiz_Inacio_Lula_da_Silva
#
# The image Luiz_Inacio_Lula_da_Silva_0007 is likely to be of class: Luiz_Inacio_Lula_da_Silva
#
# The image Luiz_Inacio_Lula_da_Silva_0011 is likely to be of class: Luiz_Inacio_Lula_da_Silva
#
# The image Luiz_Inacio_Lula_da_Silva_0038 is likely to be of class: Luiz_Inacio_Lula_da_Silva
#
# The image Luiz_Inacio_Lula_da_Silva_0028 is likely to be of class: Luiz_Inacio_Lula_da_Silva
#
# The image Luiz_Inacio_Lula_da_Silva_0014 is likely to be of class: Luiz_Inacio_Lula_da_Silva
#
# The image Luiz_Inacio_Lula_da_Silva_0015 is likely to be of class: Luiz_Inacio_Lula_da_Silva
#
# The image Luiz_Inacio_Lula_da_Silva_0016 is likely to be of class: Luiz_Inacio_Lula_da_Silva
#
# The image Paul_Bremer_0016 is likely to be of class: Paul_Bremer
#
# The image Paul_Bremer_0017 is likely to be of class: Paul_Bremer
#
# The image Paul_Bremer_0010 is likely to be of class: Paul_Bremer
#
# The image Paul_Bremer_0005 is likely to be of class: Paul_Bremer
#
# The image Paul_Bremer_0007 is likely to be of class: Paul_Bremer
#
# The image Paul_Bremer_0008 is likely to be of class: Paul_Bremer
#
# The image Paul_Bremer_0009 is likely to be of class: Paul_Bremer
#
# The image Carlos_Menem_0021 is likely to be of class: Carlos_Menem
#
# The image Carlos_Menem_0008 is likely to be of class: Carlos_Menem
#
# The image Carlos_Menem_0017 is likely to be of class: Carlos_Menem
#
# The image Carlos_Menem_0002 is likely to be of class: Carlos_Menem
#
# The image Carlos_Menem_0014 is likely to be of class: Carlos_Menem
#
# The image Carlos_Menem_0001 is likely to be of class: Carlos_Menem
#
# The image Carlos_Menem_0005 is likely to be of class: Silvio_Berlusconi
#
# The image Carlos_Menem_0004 is likely to be of class: Carlos_Menem
#
# The image Carlos_Menem_0013 is likely to be of class: Carlos_Menem
#
# The image Winona_Ryder_0024 is likely to be of class: Winona_Ryder
#
# The image Winona_Ryder_0018 is likely to be of class: Winona_Ryder
#
# The image Winona_Ryder_0019 is likely to be of class: Winona_Ryder
#
# The image Winona_Ryder_0009 is likely to be of class: Winona_Ryder
#
# The image Winona_Ryder_0020 is likely to be of class: Winona_Ryder
#
# The image Winona_Ryder_0012 is likely to be of class: Winona_Ryder
#
# The image Winona_Ryder_0013 is likely to be of class: Winona_Ryder
#
# The image Winona_Ryder_0011 is likely to be of class: Winona_Ryder
#
# The image Winona_Ryder_0001 is likely to be of class: Winona_Ryder
#
# The image Winona_Ryder_0017 is likely to be of class: Winona_Ryder
#
# The image Tom_Ridge_0010 is likely to be of class: Tom_Ridge
#
# The image Tom_Ridge_0011 is likely to be of class: Tom_Ridge
#
# The image Tom_Ridge_0013 is likely to be of class: Tom_Ridge
#
# The image Tom_Ridge_0012 is likely to be of class: Tom_Ridge
#
# The image Tom_Ridge_0016 is likely to be of class: Tom_Ridge
#
# The image Tom_Ridge_0003 is likely to be of class: Tom_Ridge
#
# The image Tom_Ridge_0029 is likely to be of class: Tom_Ridge
#
# The image Tom_Ridge_0031 is likely to be of class: Tom_Ridge
#
# The image Tom_Ridge_0032 is likely to be of class: Tom_Ridge
#
# The image Tom_Ridge_0033 is likely to be of class: Tom_Ridge
#
# The image Tom_Ridge_0023 is likely to be of class: Tom_Ridge
#
# The image Tom_Ridge_0008 is likely to be of class: Tom_Ridge
#
# The image Tom_Ridge_0009 is likely to be of class: Tom_Ridge
#
# The image Jean_Chretien_0033 is likely to be of class: Jean_Chretien
#
# The image Jean_Chretien_0019 is likely to be of class: Jean_Chretien
#
# The image Jean_Chretien_0018 is likely to be of class: Jean_Chretien
#
# The image Jean_Chretien_0024 is likely to be of class: Jean_Chretien
#
# The image Jean_Chretien_0020 is likely to be of class: Jean_Chretien
#
# The image Jean_Chretien_0022 is likely to be of class: Jean_Chretien
#
# The image Jean_Chretien_0051 is likely to be of class: Jean_Chretien
#
# The image Jean_Chretien_0046 is likely to be of class: Jean_Chretien
#
# The image Jean_Chretien_0042 is likely to be of class: Jean_Chretien
#
# The image Jean_Chretien_0055 is likely to be of class: Donald_Rumsfeld
#
# The image Jean_Chretien_0038 is likely to be of class: Jean_Chretien
#
# The image Jean_Chretien_0039 is likely to be of class: Jean_Chretien
#
# The image Jean_Chretien_0005 is likely to be of class: Jean_Chretien
#
# The image Jean_Chretien_0029 is likely to be of class: Jean_Chretien
#
# The image Jean_Chretien_0028 is likely to be of class: Jean_Chretien
#
# The image Jean_Chretien_0002 is likely to be of class: Jean_Chretien
#
# The image Jean_Chretien_0017 is likely to be of class: Jean_Chretien
#
# The image Jean_Chretien_0003 is likely to be of class: Jean_Chretien
#
# The image Andre_Agassi_0014 is likely to be of class: Andre_Agassi
#
# The image Andre_Agassi_0028 is likely to be of class: Andre_Agassi
#
# The image Andre_Agassi_0001 is likely to be of class: Andre_Agassi
#
# The image Andre_Agassi_0003 is likely to be of class: Andre_Agassi
#
# The image Andre_Agassi_0016 is likely to be of class: Andre_Agassi
#
# The image Andre_Agassi_0006 is likely to be of class: Andre_Agassi
#
# The image Andre_Agassi_0005 is likely to be of class: Andre_Agassi
#
# The image Andre_Agassi_0004 is likely to be of class: Andre_Agassi
#
# The image Andre_Agassi_0035 is likely to be of class: Andre_Agassi
#
# The image Andre_Agassi_0008 is likely to be of class: Andre_Agassi
#
# The image Andre_Agassi_0020 is likely to be of class: Andre_Agassi
#
# The image Andre_Agassi_0034 is likely to be of class: Andre_Agassi
#
# The image Andre_Agassi_0022 is likely to be of class: Andre_Agassi
#
# The image Andre_Agassi_0023 is likely to be of class: Andre_Agassi
#
# The image Andre_Agassi_0019 is likely to be of class: Andre_Agassi
#
# The image David_Beckham_0002 is likely to be of class: David_Beckham
#
# The image David_Beckham_0016 is likely to be of class: David_Beckham
#
# The image David_Beckham_0001 is likely to be of class: David_Beckham
#
# The image David_Beckham_0014 is likely to be of class: David_Beckham
#
# The image David_Beckham_0028 is likely to be of class: David_Beckham
#
# The image David_Beckham_0004 is likely to be of class: David_Beckham
#
# The image David_Beckham_0011 is likely to be of class: David_Beckham
#
# The image David_Beckham_0023 is likely to be of class: David_Beckham
#
# The image David_Beckham_0020 is likely to be of class: David_Beckham
#
# The image David_Beckham_0019 is likely to be of class: David_Beckham
#
# The image David_Beckham_0024 is likely to be of class: David_Beckham
#
# The image David_Beckham_0026 is likely to be of class: David_Beckham
#
# The image David_Beckham_0027 is likely to be of class: David_Beckham
#
# The image Donald_Rumsfeld_0001 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0007 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0004 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0005 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0062 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0117 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0063 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0088 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0075 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0115 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0101 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0060 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0104 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0105 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0111 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0073 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0107 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0066 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0094 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0057 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0081 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0097 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0040 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0121 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0041 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0118 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0050 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0093 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0091 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0085 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0046 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0047 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0053 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0084 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0090 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0008 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0034 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0009 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0037 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0032 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0027 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0025 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0024 is likely to be of class: Donald_Rumsfeld
#
# The image Donald_Rumsfeld_0030 is likely to be of class: Donald_Rumsfeld
#
# The image Laura_Bush_0027 is likely to be of class: Laura_Bush
#
# The image Laura_Bush_0025 is likely to be of class: Laura_Bush
#
# The image Laura_Bush_0030 is likely to be of class: Laura_Bush
#
# The image Laura_Bush_0020 is likely to be of class: Laura_Bush
#
# The image Laura_Bush_0008 is likely to be of class: Laura_Bush
#
# The image Laura_Bush_0021 is likely to be of class: Laura_Bush
#
# The image Laura_Bush_0023 is likely to be of class: Laura_Bush
#
# The image Laura_Bush_0022 is likely to be of class: Laura_Bush
#
# The image Laura_Bush_0007 is likely to be of class: Laura_Bush
#
# The image Laura_Bush_0006 is likely to be of class: Laura_Bush
#
# The image Laura_Bush_0012 is likely to be of class: Laura_Bush
#
# The image Laura_Bush_0038 is likely to be of class: Laura_Bush
#
# The image Laura_Bush_0011 is likely to be of class: Laura_Bush
#
# The image Laura_Bush_0029 is likely to be of class: Laura_Bush
#
# The image Laura_Bush_0014 is likely to be of class: Laura_Bush
#
# The image Laura_Bush_0016 is likely to be of class: Laura_Bush
#
# The image Laura_Bush_0002 is likely to be of class: Laura_Bush
#
# The image Arnold_Schwarzenegger_0025 is likely to be of class: Arnold_Schwarzenegger
#
# The image Arnold_Schwarzenegger_0030 is likely to be of class: Arnold_Schwarzenegger
#
# The image Arnold_Schwarzenegger_0024 is likely to be of class: Arnold_Schwarzenegger
#
# The image Arnold_Schwarzenegger_0027 is likely to be of class: Arnold_Schwarzenegger
#
# The image Arnold_Schwarzenegger_0023 is likely to be of class: Arnold_Schwarzenegger
#
# The image Arnold_Schwarzenegger_0022 is likely to be of class: Arnold_Schwarzenegger
#
# The image Arnold_Schwarzenegger_0036 is likely to be of class: Arnold_Schwarzenegger
#
# The image Arnold_Schwarzenegger_0035 is likely to be of class: Arnold_Schwarzenegger
#
# The image Arnold_Schwarzenegger_0009 is likely to be of class: Arnold_Schwarzenegger
#
# The image Arnold_Schwarzenegger_0040 is likely to be of class: Arnold_Schwarzenegger
#
# The image Arnold_Schwarzenegger_0042 is likely to be of class: Arnold_Schwarzenegger
#
# The image Arnold_Schwarzenegger_0004 is likely to be of class: Arnold_Schwarzenegger
#
# The image Arnold_Schwarzenegger_0039 is likely to be of class: Arnold_Schwarzenegger
#
# The image Arnold_Schwarzenegger_0005 is likely to be of class: Arnold_Schwarzenegger
#
# The image Arnold_Schwarzenegger_0012 is likely to be of class: Arnold_Schwarzenegger
#
# The image Arnold_Schwarzenegger_0016 is likely to be of class: Arnold_Schwarzenegger
#
# The image Juan_Carlos_Ferrero_0017 is likely to be of class: Juan_Carlos_Ferrero
#
# The image Juan_Carlos_Ferrero_0014 is likely to be of class: Juan_Carlos_Ferrero
#
# The image Juan_Carlos_Ferrero_0001 is likely to be of class: Juan_Carlos_Ferrero
#
# The image Juan_Carlos_Ferrero_0011 is likely to be of class: Juan_Carlos_Ferrero
#
# The image Juan_Carlos_Ferrero_0004 is likely to be of class: Juan_Carlos_Ferrero
#
# The image Juan_Carlos_Ferrero_0022 is likely to be of class: Juan_Carlos_Ferrero
#
# The image Juan_Carlos_Ferrero_0008 is likely to be of class: Juan_Carlos_Ferrero
#
# The image Juan_Carlos_Ferrero_0020 is likely to be of class: Juan_Carlos_Ferrero
#
# The image Juan_Carlos_Ferrero_0025 is likely to be of class: Juan_Carlos_Ferrero
#
# The image Juan_Carlos_Ferrero_0027 is likely to be of class: Juan_Carlos_Ferrero
#
# The image Juan_Carlos_Ferrero_0026 is likely to be of class: Juan_Carlos_Ferrero
#
# The image Colin_Powell_0195 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0181 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0156 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0036 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0234 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0209 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0037 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0023 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0157 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0194 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0169 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0155 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0168 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0187 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0144 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0150 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0018 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0226 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0233 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0145 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0192 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0186 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0153 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0147 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0225 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0231 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0230 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0032 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0069 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0041 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0055 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0040 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0068 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0097 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0120 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0136 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0095 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0057 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0080 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0094 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0127 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0133 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0090 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0084 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0052 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0132 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0093 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0050 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0078 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0092 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0119 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0131 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0114 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0048 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0074 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0077 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0102 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0112 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0099 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0072 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0066 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0098 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0113 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0107 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0105 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0139 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0058 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0138 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0177 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0215 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0214 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0200 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0162 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0176 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0160 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0015 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0029 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0011 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0207 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0206 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0038 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0010 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0158 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0170 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0164 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0006 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0210 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0211 is likely to be of class: Colin_Powell
#
# The image Colin_Powell_0173 is likely to be of class: Colin_Powell
#
# The image Saddam_Hussein_0019 is likely to be of class: Saddam_Hussein
#
# The image Saddam_Hussein_0020 is likely to be of class: Saddam_Hussein
#
# The image Saddam_Hussein_0010 is likely to be of class: Saddam_Hussein
#
# The image Saddam_Hussein_0005 is likely to be of class: Saddam_Hussein
#
# The image Saddam_Hussein_0013 is likely to be of class: Saddam_Hussein
#
# The image Saddam_Hussein_0012 is likely to be of class: Saddam_Hussein
#
# The image Saddam_Hussein_0016 is likely to be of class: Saddam_Hussein
#
# The image Saddam_Hussein_0015 is likely to be of class: Saddam_Hussein
#
# The image Saddam_Hussein_0001 is likely to be of class: Saddam_Hussein
#
# The image Ricardo_Lagos_0005 is likely to be of class: Ricardo_Lagos
#
# The image Ricardo_Lagos_0010 is likely to be of class: Ricardo_Lagos
#
# The image Ricardo_Lagos_0013 is likely to be of class: Ricardo_Lagos
#
# The image Ricardo_Lagos_0015 is likely to be of class: Ricardo_Lagos
#
# The image Ricardo_Lagos_0001 is likely to be of class: Ricardo_Lagos
#
# The image Ricardo_Lagos_0018 is likely to be of class: Ricardo_Lagos
#
# The image Ricardo_Lagos_0027 is likely to be of class: Ricardo_Lagos
#
# The image Ricardo_Lagos_0023 is likely to be of class: Ricardo_Lagos
#
# The image Ricardo_Lagos_0021 is likely to be of class: Ricardo_Lagos
#
# The image Jeremy_Greenstock_0023 is likely to be of class: Jeremy_Greenstock
#
# The image Jeremy_Greenstock_0009 is likely to be of class: Jeremy_Greenstock
#
# The image Jeremy_Greenstock_0024 is likely to be of class: Jeremy_Greenstock
#
# The image Jeremy_Greenstock_0017 is likely to be of class: Jeremy_Greenstock
#
# The image Jeremy_Greenstock_0004 is likely to be of class: Jeremy_Greenstock
#
# The image Jeremy_Greenstock_0010 is likely to be of class: Colin_Powell
#
# The image Jeremy_Greenstock_0012 is likely to be of class: Jeremy_Greenstock
#
# The image Lindsay_Davenport_0009 is likely to be of class: Lindsay_Davenport
#
# The image Lindsay_Davenport_0001 is likely to be of class: Lindsay_Davenport
#
# The image Lindsay_Davenport_0015 is likely to be of class: Lindsay_Davenport
#
# The image Lindsay_Davenport_0003 is likely to be of class: Lindsay_Davenport
#
# The image Lindsay_Davenport_0002 is likely to be of class: Lindsay_Davenport
#
# The image Lindsay_Davenport_0006 is likely to be of class: Lindsay_Davenport
#
# The image Lindsay_Davenport_0013 is likely to be of class: Lindsay_Davenport
#
# The image Lindsay_Davenport_0005 is likely to be of class: Lindsay_Davenport
#
# The image Lindsay_Davenport_0004 is likely to be of class: Lindsay_Davenport
#
# The image Hugo_Chavez_0003 is likely to be of class: George_Robertson
#
# The image Hugo_Chavez_0016 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0014 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0001 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0005 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0004 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0006 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0012 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0060 is likely to be of class: Guillermo_Coria
#
# The image Hugo_Chavez_0048 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0065 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0070 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0058 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0041 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0055 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0054 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0056 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0043 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0053 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0047 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0052 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0045 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0023 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0035 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0034 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0018 is likely to be of class: Hugo_Chavez
#
# The image Hugo_Chavez_0019 is likely to be of class: Hugo_Chavez
#
# The image Jennifer_Capriati_0001 is likely to be of class: Jennifer_Capriati
#
# The image Jennifer_Capriati_0028 is likely to be of class: Jennifer_Capriati
#
# The image Jennifer_Capriati_0004 is likely to be of class: Jennifer_Capriati
#
# The image Jennifer_Capriati_0012 is likely to be of class: Jennifer_Capriati
#
# ...
#
# The image George_W_Bush_0295 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0530 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0242 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0524 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0519 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0257 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0294 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0041 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0479 is likely to be of class: Tony_Blair
#
# The image George_W_Bush_0337 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0445 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0323 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0492 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0474 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0104 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0058 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0070 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0500 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0266 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0273 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0111 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0475 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0313 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0461 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0449 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0488 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0107 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0067 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0073 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0259 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0503 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0271 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0270 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0264 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0066 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0112 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0462 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0304 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0472 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0300 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0116 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0506 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0260 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0274 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0249 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0275 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0261 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0063 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0103 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0465 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0303 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0459 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0115 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0129 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0061 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0049 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0263 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0504 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0128 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0114 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0316 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0302 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0365 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0417 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0013 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0204 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0416 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0402 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0400 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0170 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0164 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0010 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0206 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0207 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0165 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0415 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0373 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0429 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0411 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0363 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0175 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0015 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0216 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0160 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0174 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0404 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0376 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0360 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0189 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0162 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0176 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0016 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0002 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0214 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0200 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0228 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0003 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0017 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0177 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0349 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0375 is likely to be of class: George_W_Bush
#
# The image George_W_Bush_0407 is likely to be of class: George_W_Bush
#
# The image Silvio_Berlusconi_0017 is likely to be of class: Silvio_Berlusconi
#
# The image Silvio_Berlusconi_0028 is likely to be of class: Silvio_Berlusconi
#
# The image Silvio_Berlusconi_0015 is likely to be of class: Silvio_Berlusconi
#
# The image Silvio_Berlusconi_0005 is likely to be of class: Silvio_Berlusconi
#
# The image Silvio_Berlusconi_0010 is likely to be of class: Silvio_Berlusconi
#
# The image Silvio_Berlusconi_0012 is likely to be of class: Silvio_Berlusconi
#
# The image Silvio_Berlusconi_0013 is likely to be of class: Silvio_Berlusconi
#
# The image Silvio_Berlusconi_0022 is likely to be of class: Silvio_Berlusconi
#
# The image Silvio_Berlusconi_0024 is likely to be of class: Silvio_Berlusconi
#
# The image Silvio_Berlusconi_0031 is likely to be of class: Silvio_Berlusconi
#
# The image Silvio_Berlusconi_0033 is likely to be of class: Silvio_Berlusconi
#
# The image Silvio_Berlusconi_0032 is likely to be of class: Silvio_Berlusconi
#
# The image Michael_Bloomberg_0005 is likely to be of class: Michael_Bloomberg
#
# The image Michael_Bloomberg_0012 is likely to be of class: Michael_Bloomberg
#
# The image Michael_Bloomberg_0006 is likely to be of class: Michael_Bloomberg
#
# The image Michael_Bloomberg_0013 is likely to be of class: Michael_Bloomberg
#
# The image Michael_Bloomberg_0002 is likely to be of class: Michael_Bloomberg
#
# The image Michael_Bloomberg_0014 is likely to be of class: Michael_Bloomberg
#
# The image Michael_Bloomberg_0009 is likely to be of class: Michael_Bloomberg
#
# The image Michael_Bloomberg_0020 is likely to be of class: Michael_Bloomberg
#
# The image Atal_Bihari_Vajpayee_0024 is likely to be of class: Atal_Bihari_Vajpayee
#
# The image Atal_Bihari_Vajpayee_0020 is likely to be of class: Atal_Bihari_Vajpayee
#
# The image Atal_Bihari_Vajpayee_0022 is likely to be of class: Atal_Bihari_Vajpayee
#
# The image Atal_Bihari_Vajpayee_0012 is likely to be of class: Atal_Bihari_Vajpayee
#
# The image Atal_Bihari_Vajpayee_0004 is likely to be of class: Atal_Bihari_Vajpayee
#
# The image Atal_Bihari_Vajpayee_0010 is likely to be of class: Atal_Bihari_Vajpayee
#
# The image Atal_Bihari_Vajpayee_0001 is likely to be of class: Atal_Bihari_Vajpayee
#
# The image Atal_Bihari_Vajpayee_0014 is likely to be of class: Atal_Bihari_Vajpayee
#
# The image Atal_Bihari_Vajpayee_0003 is likely to be of class: Atal_Bihari_Vajpayee
#
# The image Serena_Williams_0012 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0007 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0039 is likely to be of class: Jennifer_Capriati
#
# The image Serena_Williams_0038 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0004 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0029 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0016 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0050 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0047 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0052 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0046 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0043 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0033 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0026 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0019 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0025 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0009 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0035 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0036 is likely to be of class: Serena_Williams
#
# The image Serena_Williams_0037 is likely to be of class: Serena_Williams
#
# The image Megawati_Sukarnoputri_0013 is likely to be of class: Megawati_Sukarnoputri
#
# The image Megawati_Sukarnoputri_0007 is likely to be of class: Megawati_Sukarnoputri
#
# The image Megawati_Sukarnoputri_0005 is likely to be of class: Megawati_Sukarnoputri
#
# The image Megawati_Sukarnoputri_0010 is likely to be of class: Megawati_Sukarnoputri
#
# The image Megawati_Sukarnoputri_0014 is likely to be of class: Megawati_Sukarnoputri
#
# The image Megawati_Sukarnoputri_0028 is likely to be of class: Megawati_Sukarnoputri
#
# The image Megawati_Sukarnoputri_0015 is likely to be of class: Megawati_Sukarnoputri
#
# The image Megawati_Sukarnoputri_0003 is likely to be of class: Megawati_Sukarnoputri
#
# The image Megawati_Sukarnoputri_0033 is likely to be of class: Megawati_Sukarnoputri
#
# The image Megawati_Sukarnoputri_0032 is likely to be of class: Megawati_Sukarnoputri
#
# The image Megawati_Sukarnoputri_0030 is likely to be of class: Megawati_Sukarnoputri
#
# The image Megawati_Sukarnoputri_0025 is likely to be of class: Megawati_Sukarnoputri
#
# The image Megawati_Sukarnoputri_0019 is likely to be of class: Megawati_Sukarnoputri
#
# The image Gray_Davis_0010 is likely to be of class: Gray_Davis
#
# The image Gray_Davis_0013 is likely to be of class: Gray_Davis
#
# The image Gray_Davis_0012 is likely to be of class: Gray_Davis
#
# The image Gray_Davis_0017 is likely to be of class: Gray_Davis
#
# The image Gray_Davis_0019 is likely to be of class: Gray_Davis
#
# The image Gray_Davis_0025 is likely to be of class: Gray_Davis
#
# The image Gray_Davis_0023 is likely to be of class: Colin_Powell
#
# The image Gray_Davis_0020 is likely to be of class: Gray_Davis
#
# The image Gray_Davis_0008 is likely to be of class: Gray_Davis
#
# The image Guillermo_Coria_0024 is likely to be of class: Guillermo_Coria
#
# The image Guillermo_Coria_0019 is likely to be of class: Juan_Carlos_Ferrero
#
# The image Guillermo_Coria_0026 is likely to be of class: Guillermo_Coria
#
# The image Guillermo_Coria_0016 is likely to be of class: Guillermo_Coria
#
# The image Guillermo_Coria_0002 is likely to be of class: Guillermo_Coria
#
# The image Guillermo_Coria_0011 is likely to be of class: Guillermo_Coria
#
# The image Guillermo_Coria_0004 is likely to be of class: Guillermo_Coria
#
# The image Guillermo_Coria_0010 is likely to be of class: Guillermo_Coria
#
# The image Guillermo_Coria_0012 is likely to be of class: Guillermo_Coria
#
# The image Lleyton_Hewitt_0040 is likely to be of class: Lleyton_Hewitt
#
# The image Lleyton_Hewitt_0023 is likely to be of class: Lleyton_Hewitt
#
# The image Lleyton_Hewitt_0037 is likely to be of class: Lleyton_Hewitt
#
# The image Lleyton_Hewitt_0021 is likely to be of class: Lleyton_Hewitt
#
# The image Lleyton_Hewitt_0034 is likely to be of class: Lleyton_Hewitt
#
# The image Lleyton_Hewitt_0008 is likely to be of class: Lleyton_Hewitt
#
# The image Lleyton_Hewitt_0024 is likely to be of class: Lleyton_Hewitt
#
# The image Lleyton_Hewitt_0025 is likely to be of class: Lleyton_Hewitt
#
# The image Lleyton_Hewitt_0026 is likely to be of class: Lleyton_Hewitt
#
# The image Lleyton_Hewitt_0032 is likely to be of class: Lleyton_Hewitt
#
# The image Lleyton_Hewitt_0017 is likely to be of class: Lleyton_Hewitt
#
# The image Lleyton_Hewitt_0014 is likely to be of class: Lleyton_Hewitt
#
# The image Lleyton_Hewitt_0029 is likely to be of class: Lleyton_Hewitt
#
# The image Lleyton_Hewitt_0005 is likely to be of class: Lleyton_Hewitt
#
# The image Lleyton_Hewitt_0011 is likely to be of class: Lleyton_Hewitt
#
# The image Lleyton_Hewitt_0039 is likely to be of class: Lleyton_Hewitt
#
# The image Lleyton_Hewitt_0004 is likely to be of class: Lleyton_Hewitt
#
# The image John_Ashcroft_0004 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0011 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0005 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0039 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0002 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0015 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0029 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0049 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0048 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0053 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0047 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0051 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0050 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0042 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0019 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0032 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0026 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0027 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0034 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0009 is likely to be of class: John_Ashcroft
#
# The image John_Ashcroft_0035 is likely to be of class: John_Ashcroft
